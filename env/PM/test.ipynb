# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv("/home/sunshuo/qml/TradeMaster_reframe/experiment_result/data/train.csv",index_col=0)
valid=pd.read_csv("/home/sunshuo/qml/TradeMaster_reframe/experiment_result/data/valid.csv",index_col=0)
test=pd.read_csv("/home/sunshuo/qml/TradeMaster_reframe/experiment_result/data/test.csv",index_col=0)

# %%
data=train.loc[1:10,:]

# %%
data
# Out:
#           date       open       high        low      close      adjcp   tic  \
# 1   2012-01-05  14.819643  14.948214  14.738214  14.929643  12.783867  AAPL
# 1   2012-01-05  63.820000  64.919998  63.580002  64.410004  49.896770  AMGN
# 1   2012-01-05  47.840000  49.250000  47.700001  48.799999  42.156372   AXP
# 1   2012-01-05  73.769997  73.900002  72.739998  73.529999  60.166485    BA
# 1   2012-01-05  94.839996  96.160004  93.900002  95.519997  71.446198   CAT
# ..         ...        ...        ...        ...        ...        ...   ...
# 10  2012-01-19  52.310001  53.020000  51.419998  52.320000  44.645927   UNH
# 10  2012-01-19  26.040001  26.049999  25.562500  25.592501  23.822191     V
# 10  2012-01-19  38.990002  39.119999  38.889999  39.000000  24.605272    VZ
# 10  2012-01-19  33.310001  33.889999  33.060001  33.500000  25.494814   WBA
# 10  2012-01-19  59.930000  60.730000  59.750000  60.610001  47.933495   WMT
#
# ...

# %%
data.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'adjcp', 'tic', 'zopen',
#        'zhigh', 'zlow', 'zadjcp', 'zclose', 'zd_5', 'zd_10', 'zd_15', 'zd_20',
#        'zd_25', 'zd_30'],
#       dtype='object')

# %%
train.loc[10,:]
# Out:
#           date        open        high         low       close       adjcp  \
# 10  2012-01-19   15.362500   15.406071   15.232500   15.276786   13.081120
# 10  2012-01-19   69.139999   69.489998   68.699997   69.139999   53.560982
# 10  2012-01-19   50.709999   51.000000   50.459999   50.950001   44.013691
# 10  2012-01-19   75.269997   75.919998   75.099998   75.559998   61.827549
# 10  2012-01-19  104.650002  105.760002  103.629997  105.750000   79.451530
# 10  2012-01-19   27.837500   28.969999   27.837500   28.627501   28.627501
# 10  2012-01-19   19.680000   19.950001   19.600000   19.790001   14.521701
# 10  2012-01-19  107.209999  107.500000  105.820000  106.930000   70.133606
# 10  2012-01-19   39.009998   39.470001   39.000000   39.439999   35.312351
# 10  2012-01-19  106.250000  108.300003  104.879997  107.680000   91.322044
# 10  2012-01-19   44.869999   45.419998   44.450001   45.410000   36.203087
# ...

# %%
max([1,2,3,4])
# Out:
# 4

# %%
max(2,3)
# Out:
# 3

# %%
import heapq
score=[1,2,3,34,5,7]
re1 = map(score.index, heapq.nlargest(3, score))
big_list=list(re1)
top_score=[0]*len(score)

# %%
import torch
len(torch.tensor([1,2,3]))
# Out:
# 3

# %%
a=[12,3,4,5,56,6]

# %%
a[2]=3
a
# Out:
# [12, 3, 3, 5, 56, 6]

# %%
import random
random.sample(range(100),int(100/10))
# Out:
# [51, 3, 24, 6, 57, 64, 59, 79, 47, 7]

# %%
0+torch.tensor([1])
# Out:
# tensor([1])

# %%
import torch
torch.tensor(1)+torch.tensor([1])
# Out:
# tensor([2])

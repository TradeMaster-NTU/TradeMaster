# %%
import numpy as np
import pandas as pd
data=pd.read_csv("/home/sunshuo/qml/TradeMaster-1/competition/data/train.csv",index_col=0)

# %%
data
# Out:
#          zopen     zhigh      zlow    zadjcp    zclose      zd_5     zd_10  \
# 0    -0.008320  0.002999 -0.010062 -0.143726  0.005374 -0.010348 -0.011415
# 0     0.005332  0.005803 -0.005646 -0.225326 -0.005459  0.007794 -0.008521
# 0    -0.004561  0.002902 -0.017413 -0.136140 -0.003100  0.004561 -0.004885
# 0    -0.003094  0.003632 -0.009956 -0.181742  0.001482  0.002922 -0.007421
# 0    -0.015182  0.006958 -0.015182 -0.252029  0.009257  0.010322 -0.004803
# ...        ...       ...       ...       ...       ...       ...       ...
# 2010 -0.005861  0.000595 -0.008884 -0.048781  0.004924  0.004808  0.004437
# 2010 -0.003051  0.000452 -0.008701 -0.044475  0.003288 -0.002158 -0.003520
# 2010 -0.011265  0.000597 -0.012235 -0.106114  0.009261  0.002701  0.004432
# 2010 -0.003843  0.001337 -0.008187 -0.056113  0.003858 -0.001571 -0.015221
# 2010 -0.005279  0.000960 -0.007472 -0.056455  0.003923 -0.000919 -0.003716
#
#          zd_15     zd_20     zd_25     zd_30  date       close  tic
# ...

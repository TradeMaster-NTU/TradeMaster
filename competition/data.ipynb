# %%
import numpy as np
import pandas as pd
data=pd.read_csv("/home/sunshuo/qml/TradeMaster-1/competition/data/train.csv",index_col=0)

# %%
data
# Out:
#          zopen     zhigh      zlow    zadjcp    zclose      zd_5     zd_10  \
# 0    -0.008320  0.002999 -0.010062 -0.143726  0.005374 -0.010348 -0.011415
# 0     0.005332  0.005803 -0.005646 -0.225326 -0.005459  0.007794 -0.008521
# 0    -0.004561  0.002902 -0.017413 -0.136140 -0.003100  0.004561 -0.004885
# 0    -0.003094  0.003632 -0.009956 -0.181742  0.001482  0.002922 -0.007421
# 0    -0.015182  0.006958 -0.015182 -0.252029  0.009257  0.010322 -0.004803
# ...        ...       ...       ...       ...       ...       ...       ...
# 2010 -0.005861  0.000595 -0.008884 -0.048781  0.004924  0.004808  0.004437
# 2010 -0.003051  0.000452 -0.008701 -0.044475  0.003288 -0.002158 -0.003520
# 2010 -0.011265  0.000597 -0.012235 -0.106114  0.009261  0.002701  0.004432
# 2010 -0.003843  0.001337 -0.008187 -0.056113  0.003858 -0.001571 -0.015221
# 2010 -0.005279  0.000960 -0.007472 -0.056455  0.003923 -0.000919 -0.003716
#
#          zd_15     zd_20     zd_25     zd_30  date       close  tic
# ...

# %%
needed_feature=data.columns

# %%
test_input=pd.read_csv("/home/sunshuo/qml/TradeMaster-1/data/data/dj30/test.csv",index_col=0)
test_input
tic_list=test_input.tic.unique()
df=pd.DataFrame()
for i,tic in zip(range(15),tic_list[:15]):
    single_tic_information=test_input[test_input.tic==tic]
    single_tic_information["tic"]=i
    df=df.append(single_tic_information)
df=df.sort_values(by=["date","tic"])
df["date"]=df.index
df=df[needed_feature]
df
# Out:
# /home/sunshuo/miniconda3/envs/TradeMaster/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#         zopen     zhigh      zlow    zadjcp    zclose      zd_5     zd_10  \
# 0    0.031760  0.032455 -0.020478 -0.007392 -0.024719  0.031420  0.017758
# 0    0.020251  0.020251 -0.013192 -0.038254 -0.014179  0.000856 -0.004266
# 0    0.027618  0.031854 -0.010081 -0.016789 -0.023737  0.007930 -0.002330
# 0    0.035912  0.036898 -0.001135  0.000000 -0.052976  0.051490  0.065741
# 0    0.004667  0.021027 -0.010431 -0.029845  0.000714 -0.012649 -0.014598
# ..        ...       ...       ...       ...       ...       ...       ...
# ...

# %%
dates_1=range(0,251,30)
length=len(dates_1)
df_1=pd.DataFrame()
for date in (dates_1):
    single_date_information=df[df.date==date]
    print(date)
    df_1=df_1.append(single_date_information)
df_1
# Out:
# 0
# 30
# 60
# 90
# 120
# 150
# 180
# 210
# 240
#         zopen     zhigh      zlow    zadjcp    zclose      zd_5     zd_10  \
# 0    0.031760  0.032455 -0.020478 -0.007392 -0.024719  0.031420  0.017758
# 0    0.020251  0.020251 -0.013192 -0.038254 -0.014179  0.000856 -0.004266
# 0    0.027618  0.031854 -0.010081 -0.016789 -0.023737  0.007930 -0.002330
# 0    0.035912  0.036898 -0.001135  0.000000 -0.052976  0.051490  0.065741
# 0    0.004667  0.021027 -0.010431 -0.029845  0.000714 -0.012649 -0.014598
# ..        ...       ...       ...       ...       ...       ...       ...
# 240 -0.017631  0.000294 -0.020647 -0.005999  0.013948  0.001442  0.005542
# 240 -0.010536  0.003051 -0.021548 -0.005476  0.014902 -0.006979 -0.014574
# 240  0.005605  0.013890 -0.007554 -0.011902 -0.005252  0.002534 -0.011161
# 240 -0.015788  0.002171 -0.026446 -0.007560  0.019517 -0.007539 -0.002368
# 240 -0.007538  0.000935 -0.010050 -0.006378  0.004992 -0.016863 -0.036824
#
# ...
